# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense
import matplotlib.pyplot as plt

# %%
# 1. 데이터 로드
df = pd.read_csv("C:/Users/LIM/OneDrive - gachon.ac.kr/바탕 화면/study/인공지능개론/AAME.csv", parse_dates=['Date'], index_col='Date')

# %%
# 2. 사용할 칼럼 선택 (adj close, volume 제외)
df_features = df[['Open', 'High', 'Low', 'Close']]
df_target   = df[['Close']]

# %%
# 3. 0~1 사이로 정규화
scaler_feat   = MinMaxScaler()
features_scaled = scaler_feat.fit_transform(df_features)

scaler_target = MinMaxScaler()
target_scaled  = scaler_target.fit_transform(df_target)

# %%
# 4. 시퀀스 생성 함수
def create_sequences(features, target, window=10):
    X, y = [], []
    for i in range(len(features) - window):
        X.append(features[i : i + window])
        y.append(target[i + window])
    return np.array(X), np.array(y)

window = 10
X, y = create_sequences(features_scaled, target_scaled, window)

# %%
# 5. 학습/테스트 분리 (시계열 유지)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# %%
# 6. LSTM 모델 구성
model = Sequential([
    Input(shape=(window, X.shape[2])),  # (10 timesteps, 4 features)
    LSTM(50, activation='tanh'),        # LSTM 셀 50개
    Dense(1, activation='linear')       # 실수 예측용 출력
])
model.compile(optimizer='adam', loss='mse')

# %%
# 7. 모델 학습
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0091 - val_loss: 8.0542e-05
# Epoch 2/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9547e-04 - val_loss: 7.1543e-05
# Epoch 3/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8879e-04 - val_loss: 7.1016e-05
# Epoch 4/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 2.0498e-04 - val_loss: 6.7459e-05
# Epoch 5/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.6975e-04 - val_loss: 6.4143e-05
# Epoch 6/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.4401e-04 - val_loss: 1.2024e-04
# Epoch 7/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.3786e-04 - val_loss: 5.3643e-05
# Epoch 8/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.4213e-04 - val_loss: 5.8556e-05
# Epoch 9/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.2001e-04 - val_loss: 6.4806e-05
# Epoch 10/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.1772e-04 - val_loss: 5.6232e-05
# Epoch 11/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 1.1413e-04 - val_loss: 4.6488e-05
# Epoch 12/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.0451e-04 - val_loss: 5.1542e-05
# Epoch 13/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.2128e-04 - val_loss: 4.4549e-05
# Epoch 14/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.7784e-05 - val_loss: 4.3996e-05
# Epoch 15/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.0551e-04 - val_loss: 4.2816e-05
# Epoch 16/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.0269e-04 - val_loss: 4.3707e-05
# Epoch 17/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.7671e-05 - val_loss: 4.1422e-05
# Epoch 18/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 9.3686e-05 - val_loss: 4.1815e-05
# Epoch 19/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.5449e-05 - val_loss: 5.4050e-05
# Epoch 20/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 9.2802e-05 - val_loss: 8.1660e-05
# Epoch 21/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 8.9956e-05 - val_loss: 4.2910e-05
# Epoch 22/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.5152e-05 - val_loss: 4.1850e-05
# Epoch 23/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.6267e-05 - val_loss: 3.8350e-05
# Epoch 24/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.4542e-05 - val_loss: 4.8708e-05
# Epoch 25/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.7875e-05 - val_loss: 4.9553e-05
# Epoch 26/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.3643e-05 - val_loss: 3.9938e-05
# Epoch 27/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.5449e-05 - val_loss: 4.4987e-05
# Epoch 28/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.4280e-05 - val_loss: 5.1068e-05
# Epoch 29/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.2049e-05 - val_loss: 3.8038e-05
# Epoch 30/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.2382e-05 - val_loss: 4.1803e-05
# Epoch 31/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.1247e-05 - val_loss: 3.9683e-05
# Epoch 32/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.7638e-05 - val_loss: 3.7587e-05
# Epoch 33/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 7.8724e-05 - val_loss: 4.0225e-05
# Epoch 34/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.8479e-05 - val_loss: 4.1623e-05
# Epoch 35/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.8147e-05 - val_loss: 3.9186e-05
# Epoch 36/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8526e-05 - val_loss: 5.4700e-05
# Epoch 37/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.2703e-05 - val_loss: 3.7250e-05
# Epoch 38/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.9472e-05 - val_loss: 4.8386e-05
# Epoch 39/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.1234e-05 - val_loss: 7.4776e-05
# Epoch 40/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.2936e-05 - val_loss: 4.4513e-05
# Epoch 41/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.9283e-05 - val_loss: 4.0110e-05
# Epoch 42/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.4786e-05 - val_loss: 4.3554e-05
# Epoch 43/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.0863e-05 - val_loss: 6.0872e-05
# Epoch 44/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.5429e-05 - val_loss: 3.7602e-05
# Epoch 45/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.8433e-05 - val_loss: 3.7281e-05
# Epoch 46/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.9380e-05 - val_loss: 4.3127e-05
# Epoch 47/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.0850e-05 - val_loss: 3.7628e-05
# Epoch 48/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.6778e-05 - val_loss: 5.4829e-05
# Epoch 49/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.3777e-05 - val_loss: 4.1811e-05
# Epoch 50/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.7684e-05 - val_loss: 4.3949e-05

# %%
# 8. 예측 및 역스케일
y_pred      = model.predict(X_test)
y_pred_inv  = scaler_target.inverse_transform(y_pred)
y_test_inv  = scaler_target.inverse_transform(y_test)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
# 9. 시각화
plt.figure(figsize=(10, 4))
plt.plot(y_test_inv,  label='True Close')
plt.plot(y_pred_inv,  label='Predicted Close', linestyle='--')
plt.title('AAME Close Price Prediction with LSTM')
plt.xlabel('Time Step')
plt.ylabel('Close Price')
plt.legend()
plt.show()
